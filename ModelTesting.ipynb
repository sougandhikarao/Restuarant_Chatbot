# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"

# %% [markdown]
# ## Installing Necessary Libraries and Modules

# %%
! pip -q install transformers
! pip -q install evaluate
! pip -q install bert_score
! pip -q install rouge_score
! pip -q install sacrebleu
# Out:
#      |████████████████████████████████| 5.5 MB 4.2 MB/s
#      |████████████████████████████████| 163 kB 65.8 MB/s
#      |████████████████████████████████| 7.6 MB 36.5 MB/s
#      |████████████████████████████████| 72 kB 1.0 MB/s
#      |████████████████████████████████| 441 kB 10.2 MB/s
#      |████████████████████████████████| 212 kB 57.2 MB/s
#      |████████████████████████████████| 115 kB 64.8 MB/s
#      |████████████████████████████████| 95 kB 4.5 MB/s
#      |████████████████████████████████| 127 kB 33.9 MB/s
#      |████████████████████████████████| 115 kB 38.5 MB/s
#      |████████████████████████████████| 60 kB 3.3 MB/s
#   Building wheel for rouge-score (setup.py) ... done
#      |████████████████████████████████| 118 kB 4.8 MB/s

# %% [markdown]
# ## Import Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
import pandas as pd
import numpy as np
import evaluate

# %% [markdown]
# ## Model Loading

# %%
model_size = "small" 
tokenizer = AutoTokenizer.from_pretrained(f'microsoft/DialoGPT-{model_size}')
model = AutoModelForCausalLM.from_pretrained(f'/content/drive/MyDrive/ChatBotProject/output/output-{model_size}')

# %% [markdown]
# ## Loading test data

# %%
val_data = pd.read_excel("/content/drive/MyDrive/ChatBotProject/input/validation_data.xlsx")
val_data.head()
# Out:
#                           Questions By Customer  \
# 0  I would like to book a table for five people
# 1       Is it possible to cancel my reservation
# 2                       who am i speaking with?
# 3                    Hey are u the new chatbot?
# 4                     Adam how are you feeling?
#
#                                  Response By Chatbot
# 0  Sure! I can process your request. Let me check...
# 1               Sure, I can cancel your reservation.
# 2  Hello, I am Adam and i am here to assist you t...
# 3                                  I am Adam chatbot
# 4                          i am great what about you

# %%
validation_questions=val_data['Questions By Customer'].values
true_answers=val_data['Response By Chatbot'].values

# %%
print(validation_questions)
# Out:
# ['I would like to book a table for five people'
#  'Is it possible to cancel my reservation' 'who am i speaking with?'
#  'Hey are u the new chatbot?' 'Adam how are you feeling?'
#  'How many people can fit in the restuarant'
#  'I would like to hold a party event' 'Yo Adam watsapp'
#  'I loved your restuarant food' 'Thank You Adam'
#  'Does Robusta beans contain caffeine and how do they taste'
#  'I want to drink a cup of tea, what are the available options'
#  'I want to drink a cup of coffee, what are the available options'
#  'What are the benifits of drinking a coffee, does it contain any nutrients '
#  'What process is followed to make a tea bag'
#  'Can you explain what does gluten-free means'
#  'can you give me the options of milk used for tea and coffee'
#  'Are noodles healthy to eat at your restaurant'
#  'Do you take care of temperature while brewing a coffee'
#  'Can I choose the flour type used to prepare noodles'
#  'what receipe do you follow to prepare noodles'
#  'what at are hot drinks at your restaurant?'
#  'what you suggest for the main course?'
#  'can you take the order of  hot tea?'
#  'can you place the order of vegan pasta?' 'i want to order venti coffee'
#  'want to order vegan noodles for the lunch'
#  'Can you add honey for tea instead of sugar'
#  'Adam tell me the restaurant speciality food option'
#  'what is mean by vegan food?'
#  'i want to cancel my order and need my refund'
#  'want to modify my order and cancel my previous order'
#  'could we see the tea drink menu please?'
#  'do you have alcohol in resturant?' 'adam do you serve the chinese food?'
#  ' want to order chicken soup' 'want to verify the order?'
#  'recommend me the healthy tea option']

# %%
print(true_answers)
# Out:
# ['Sure! I can process your request. Let me check the availability'
#  'Sure, I can cancel your reservation.'
#  'Hello, I am Adam and i am here to assist you today' 'I am Adam chatbot'
#  'i am great what about you' 'You want to book restaurant for party event'
#  'Could you please tell me how many people are accompanying you'
#  'Hi! How may I assist you today?'
#  'Thanks for the positive feedback. Hope you liked our restaurant'
#  "It's been my pleasure serving you!"
#  'Robusta beans are typically cheaper to produce because the Robusta plant is easier to grow. They have a higher caffeine content and taste more bitter than Arabica beans. These beans are often used to make instant coffee and espresso blends.'
#  'Sure! We have many varieties of Tea like Green Tea,Lemon Tea and Ginger Tea. May I know which one you prefer ?'
#  'Sure! what type of coffee do you prefer ? We have Espresso, Mocha Latte and Macchiato'
#  'Coffee contains caffeine, the most commonly consumed stimulant in the world and is widely used to benefit alertness as well as physical performance. It is also commonly linked to weight loss as caffeine can also increase a person’s metabolic rate by anywhere between 3-11%. Coffee also contains nutrients such as B2, B3, B5, Manganese and Potassium which are recommended as part of a healthy diet.'
#  'our teabags are made in Japan out of a different, completely plant-based material: polylactic acid (PLA), derived from corn. Once filled with tea, the bags are electrostatically sealed, requiring no glue or metal staples—ensuring the flavor of the tea is all you taste in your cup. PLA is biodegradable when processed in a commercial composting facility.'
#  'A gluten-free diet is an eating plan that excludes foods containing gluten.'
#  'we use high quality gras-fed milk along with other cutomizable options like whole milk, 2% fat free milk and almond milk'
#  'All the noodles are high quality and tested specifically for retaining all the nutrients. '
#  'We follow different temperatures for different types of coffee, so that each falvour is perfectly blended'
#  'We have two flour options Wheat and All purpose flour, which one would you prefer '
#  'we use in-house recipe for all the items and maximize use of in-house cheese and sauses to make to the best tyaste and health'
#  'We have tea and coffee serverd as hot drinks at our restaurant'
#  'The resturant currently offers only noodles as the main course, you have five options to choose from noodles types'
#  'Sure! We have many varieties of Tea like Green Tea,Lemon Tea and Ginger Tea. May I know which one you prefer ?'
#  'Thanks for the order! Your Pasta noodles will be ready in 20 minutes.'
#  'Sure! what type of coffee do you prefer ? We have Espresso, Mocha Latte and Macchiato'
#  'yes, please let me know what type of noodles would you like to order? We have Soba Noodles, Ramen Noodles and Pasta Noodles.'
#  'Sorry we do not have that option, would you like to make it sugar free?'
#  'We have options available to place order in Noodles, Tea and Coffee'
#  ' yes,A vegan diet is based on plants (such as vegetables, grains, nuts and fruits) and foods made from plants'
#  'Sure I will cancel the order that is placed, is there any particular reason for cancelling the order.'
#  'Sure please tell me what would you like to modify in the order you placed today at our resturant'
#  'There are three types of tea we are offering at our resturant they are Green Tea, Lemon Tea and Ginger Tea'
#  'We have tea and coffee serverd as hot drinks at our resturant'
#  'We have a wide range of options available in noodles for chinese food lovers'
#  'No sorry unfortunately we do not offer any other items other than coffe, tea and noodles'
#  'Yes definitely, the order details you ordered is shown to you on the screen now you can review it'
#  'A tea lover with health concious can try black tea or green tea at our resturant']

# %% [markdown]
# ## Model prediction

# %%
predicted_answers=[]
for question in validation_questions:
  new_user_input_ids = tokenizer.encode(question + tokenizer.eos_token, return_tensors='pt')
  bot_input_ids = torch.cat([new_user_input_ids], dim=-1)
  chat_history_ids = model.generate(bot_input_ids, max_length=1000,pad_token_id=tokenizer.eos_token_id,  no_repeat_ngram_size=3,do_sample=True, top_k=100, top_p=0.7,temperature = 0.8)
  predicted_answers.append(tokenizer.decode(chat_history_ids[:, bot_input_ids.shape[-1]:][0], skip_special_tokens=True))
# Out:
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.

# %%
result=pd.DataFrame(data={"True Answers":true_answers,"Predicted Answers":predicted_answers})
result=result.sample(frac=1).reset_index(drop=True)
result.head()
# Out:
#                                         True Answers  \
# 0  Could you please tell me how many people are a...
# 1  Thanks for the order! Your Pasta noodles will ...
# 2  Sure! what type of coffee do you prefer ? We h...
# 3  Hello, I am Adam and i am here to assist you t...
# 4  we use in-house recipe for all the items and m...
#
#                                    Predicted Answers
# 0       Yes I am here to help you. what's your name?
# 1  Yes,A vegan diet is based on plants (such as v...
# 2  Sure! what type of coffee do you prefer? We ha...
# 3                                  I am Adam chatbot
# 4  We follow different temperatures for different...

# %%
val_data_ans=result['True Answers'].values
predicted_sents=result['Predicted Answers'].values

# %% [markdown]
# ### BLEU SCORE

# %%
import nltk
BLEU_scores=[]
for i in range(len(val_data_ans)):
    hypothesis = predicted_sents[i]
    reference = val_data_ans[i]
    B_score = nltk.translate.bleu_score.sentence_bleu([reference], hypothesis)
    BLEU_scores.append(B_score)
print("BLEU score is {}".format(np.mean(BLEU_scores)))
# Out:
# BLEU score is 0.4884521411436808

# %% [markdown]
# ### Precision, Recall and F1 Score

# %%
from evaluate import load
bertscore = load("bertscore")
predictions = predicted_sents
references = val_data_ans
results = bertscore.compute(predictions=predictions, references=references, lang="en")
print("Precision score - {}".format(np.mean(results['precision'])))
print("Recall score - {}".format(np.mean(results['recall'])))
print("F1 score - {}".format(np.mean(results['f1'])))
# Out:
# Downloading builder script:   0%|          | 0.00/7.95k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/482 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.43G [00:00<?, ?B/s]
# Precision score - 0.9139922010271173
# Recall score - 0.9112933576107025
# F1 score - 0.9125735195059526

# %% [markdown]
# ### Perplexity

# %%
perplexity = load("perplexity", module_type="metric")
results_pxty = perplexity.compute(predictions=predicted_sents, model_id='gpt2')
print("Perplexity value : {}".format(results_pxty['mean_perplexity']))
# Out:
# Downloading builder script:   0%|          | 0.00/8.41k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Using pad_token, but it is not set yet.
#   0%|          | 0/3 [00:00<?, ?it/s]
# Perplexity value : 134.49190184944555

# %% [markdown]
# ### ROUGE

# %%
rouge = evaluate.load('rouge')
results = rouge.compute(predictions=predictions,references=references)
print("Rouge value : {}".format(results['rouge1']))
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]
# Rouge value : 0.4999208605220576

# %% [markdown]
# ### METEOR

# %%
meteor = evaluate.load('meteor')
results = meteor.compute(predictions=predictions, references=references)
print("METEOR score is {}".format(results['meteor']))
# Out:
# Downloading builder script:   0%|          | 0.00/6.81k [00:00<?, ?B/s]
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# METEOR score is 0.4778000300402429

# %% [markdown]
# ### TER

# %%
ter = evaluate.load("ter")
results = ter.compute(predictions=predictions,references=references,case_sensitive=True)
print("TER score : {}".format(results['score']))
# Out:
# Downloading builder script:   0%|          | 0.00/9.99k [00:00<?, ?B/s]
# TER score : 71.10778443113772
